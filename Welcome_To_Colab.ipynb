# %% [markdown]
# <a href="https://colab.research.google.com/github/chkaran268-max/AI-in-data-science/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
sr={
    "name": pd.Series(["hardik","vijay","jatin"]),
    "marks":pd.Series([44,88,66])
    }
df=pd.DataFrame(sr)
df
# Out:
#      name  marks
# 0  hardik     44
# 1   vijay     88
# 2   jatin     66

# %% [markdown]
# ##insert in pandas frame

# %%
info=pd.DataFrame({"name":["hardik","vijay","jatin"]})
info.insert(1,"age",info["name"]) #copy from previous column
info.insert(2,"city",info["delhi","up"]) #insert manually
